# %% [markdown]
# <a href="https://colab.research.google.com/github/lakshmip04/DATASCIENCE/blob/main/FDSTIMESERIES1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
from google.colab import drive
drive.mount('/content/drive')
# !ls "/content/drive/My Drive/"
# Out:
# Mounted at /content/drive
# 'Certificate-Workshop-lakshmi priya.pdf'		    'Untitled document (1).gdoc'
# 'Colab Notebooks'					    'Untitled document.gdoc'
# 'Copy of LabSessionData.xlsx'				    'Untitled form (1).gform'
# 'Lakshmi_Priya_Resume_ _.pdf'				    'Untitled form (2).gform'
#  LakshmiPriya_Resume.pdf				    'Untitled form (3).gform'
# 'ml project NID.gdoc'					    'Untitled form.gform'
# 'Prevention of SDN Route Manipulation Attack.gdoc'	    'Untitled form (Responses) (1).gsheet'
# 'Receipt pay_OlCdMSW3u0OXdL from NEXT CHAPTER  (Paid).pdf'  'Untitled form (Responses).gsheet'
#  SDN.gdoc						     YLS_LakshmiPriya.gdoc

# %%
df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/FDS/yearly_data.xlsx')
df
# Out:
#           Date         DisNo. Historic Classification Key Disaster Group  \
# 0   1970-01-01  2000-0020-IND       No    nat-met-ext-col        Natural
# 1   1970-01-01  2000-0306-IND       No    nat-bio-epi-vir        Natural
# 2   1970-01-01  2000-0308-IND       No    nat-bio-epi-bac        Natural
# 3   1970-01-01  2000-0323-IND       No    nat-met-sto-tro        Natural
# 4   1970-01-01  2000-0332-IND       No    nat-hyd-flo-fla        Natural
# ..         ...            ...      ...                ...            ...
# 404 1970-01-01  2024-0399-IND       No    nat-hyd-flo-fla        Natural
# 405 1970-01-01  2024-0481-IND       No    nat-hyd-flo-flo        Natural
# 406 1970-01-01  2024-0561-IND       No    nat-hyd-flo-flo        Natural
# 407 1970-01-01  2024-0624-IND       No    nat-hyd-flo-fla        Natural
# 408 1970-01-01  2024-0627-IND       No    nat-hyd-mmw-lan        Natural
#
#     Disaster Subgroup  Disaster Type   Disaster Subtype  ISO Country  ...  \
# 0      Meteorological              3          Cold wave  IND   India  ...
# 1          Biological              2      Viral disease  IND   India  ...
# 2          Biological              2  Bacterial disease  IND   India  ...
# 3      Meteorological              8   Tropical cyclone  IND   India  ...
# 4        Hydrological              4        Flash flood  IND   India  ...
# ..                ...            ...                ...  ...     ...  ...
# 404      Hydrological              4        Flash flood  IND   India  ...
# 405      Hydrological              4    Flood (General)  IND   India  ...
# 406      Hydrological              4    Flood (General)  IND   India  ...
# 407      Hydrological              4        Flash flood  IND   India  ...
# 408      Hydrological              7    Landslide (wet)  IND   India  ...
#
#     End Year End Month End Day Total Deaths  No. Affected Total Affected  \
# 0       2000         1       1   275.000000  5.141636e+06   3.935890e+06
# 1       2000         5       1    84.000000  1.055000e+03   1.055000e+03
# 2       2000         5       1   240.103448  1.920000e+02   1.920000e+02
# 3       2000        10      17   240.103448  5.141636e+06   3.935890e+06
# 4       2000         6      10    20.000000  3.000000e+06   3.000000e+06
# ..       ...       ...     ...          ...           ...            ...
# 404     2024         7       8    48.000000  2.100000e+06   2.100000e+06
# 405     2024         7       9   125.000000  1.000000e+06   1.000020e+06
# 406     2024         8      23    46.000000  5.141636e+06   3.935890e+06
# 407     2024         8      19    11.000000  3.400000e+04   3.400000e+04
# 408     2024         8      22    10.000000  9.000000e+01   9.000000e+01
#
#            CPI                                        Admin Units  Entry Date  \
# 0    56.514291  [{"adm1_code":1511,"adm1_name":"West Bengal"},...  2003-07-01
# 1    56.514291  [{"adm1_code":70081,"adm1_name":"Uttar Pradesh"}]  2003-07-01
# 2    56.514291  [{"adm1_code":70081,"adm1_name":"Uttar Pradesh"}]  2003-07-01
# 3    56.514291  [{"adm1_code":1485,"adm1_name":"Andhra Pradesh"}]  2003-07-01
# 4    56.514291  [{"adm2_code":17582,"adm2_name":"Golaghat"},{"...  2005-09-15
# ..         ...                                                ...         ...
# 404  73.203269  [{"adm1_code":70081,"adm1_name":"Uttar Pradesh"}]  2024-06-21
# 405  73.203269  [{"adm1_code":70081,"adm1_name":"Uttar Pradesh"}]  2024-07-15
# 406  73.203269  [{"adm1_code":70081,"adm1_name":"Uttar Pradesh"}]  2024-08-01
# 407  73.203269  [{"adm1_code":70081,"adm1_name":"Uttar Pradesh"}]  2024-08-23
# 408  73.203269  [{"adm1_code":70081,"adm1_name":"Uttar Pradesh"}]  2024-08-22
#
#      Last Update
# 0     2023-09-25
# 1     2023-09-25
# 2     2023-09-25
# 3     2023-09-25
# 4     2023-09-25
# ..           ...
# 404   2024-07-18
# 405   2024-07-23
# 406   2024-08-23
# 407   2024-08-23
# 408   2024-08-23
#
# [409 rows x 33 columns]

# %%
# Ensure 'End Day', 'End Month', and 'End Year' are integers or valid strings
df['End Day'] = df['End Day'].astype(str).str.zfill(2)  # Ensures day is two digits
df['End Month'] = df['End Month'].astype(str).str.zfill(2)  # Ensures month is two digits
df['End Year'] = df['End Year'].astype(str)  # Ensure year is a string

# Combine the columns to form a date
df['yearMonth'] = pd.to_datetime(df['End Year'] + '-' + df['End Month'] + '-' + df['End Day'], errors='coerce')

# Set the new column as the index
df.set_index('yearMonth', inplace=True)

# Display the first few rows of the DataFrame
df.head()
# Out:
#                  Date         DisNo. Historic Classification Key  \
# yearMonth
# 2000-01-01 1970-01-01  2000-0020-IND       No    nat-met-ext-col
# 2000-05-01 1970-01-01  2000-0306-IND       No    nat-bio-epi-vir
# 2000-05-01 1970-01-01  2000-0308-IND       No    nat-bio-epi-bac
# 2000-10-17 1970-01-01  2000-0323-IND       No    nat-met-sto-tro
# 2000-06-10 1970-01-01  2000-0332-IND       No    nat-hyd-flo-fla
#
#            Disaster Group Disaster Subgroup  Disaster Type   Disaster Subtype  \
# yearMonth
# 2000-01-01        Natural    Meteorological              3          Cold wave
# 2000-05-01        Natural        Biological              2      Viral disease
# 2000-05-01        Natural        Biological              2  Bacterial disease
# 2000-10-17        Natural    Meteorological              8   Tropical cyclone
# 2000-06-10        Natural      Hydrological              4        Flash flood
#
#             ISO Country  ... End Year End Month End Day Total Deaths  \
# yearMonth                ...
# 2000-01-01  IND   India  ...     2000        01      01   275.000000
# 2000-05-01  IND   India  ...     2000        05      01    84.000000
# 2000-05-01  IND   India  ...     2000        05      01   240.103448
# 2000-10-17  IND   India  ...     2000        10      17   240.103448
# 2000-06-10  IND   India  ...     2000        06      10    20.000000
#
#             No. Affected Total Affected        CPI  \
# yearMonth
# 2000-01-01  5.141636e+06   3.935890e+06  56.514291
# 2000-05-01  1.055000e+03   1.055000e+03  56.514291
# 2000-05-01  1.920000e+02   1.920000e+02  56.514291
# 2000-10-17  5.141636e+06   3.935890e+06  56.514291
# 2000-06-10  3.000000e+06   3.000000e+06  56.514291
#
#                                                   Admin Units  Entry Date  \
# yearMonth
# 2000-01-01  [{"adm1_code":1511,"adm1_name":"West Bengal"},...  2003-07-01
# 2000-05-01  [{"adm1_code":70081,"adm1_name":"Uttar Pradesh"}]  2003-07-01
# 2000-05-01  [{"adm1_code":70081,"adm1_name":"Uttar Pradesh"}]  2003-07-01
# 2000-10-17  [{"adm1_code":1485,"adm1_name":"Andhra Pradesh"}]  2003-07-01
# 2000-06-10  [{"adm2_code":17582,"adm2_name":"Golaghat"},{"...  2005-09-15
#
#             Last Update
# yearMonth
# 2000-01-01   2023-09-25
# 2000-05-01   2023-09-25
# 2000-05-01   2023-09-25
# 2000-10-17   2023-09-25
# 2000-06-10   2023-09-25
#
# [5 rows x 33 columns]

# %%
sns.lineplot(data=df, x=df.index, y='Total Affected')
# Out:
# <Axes: xlabel='yearMonth', ylabel='Total Affected'>

# %%
df.columns
# Out:
# Index(['Date', 'DisNo.', 'Historic', 'Classification Key', 'Disaster Group',
#        'Disaster Subgroup', 'Disaster Type', 'Disaster Subtype', 'ISO',
#        'Country', 'Subregion', 'Region', 'Location', 'OFDA/BHA Response',
#        'Appeal', 'Declaration', 'Magnitude', 'Magnitude Scale', 'Latitude',
#        'Longitude', 'Start Year', 'Start Month', 'Start Day', 'End Year',
#        'End Month', 'End Day', 'Total Deaths', 'No. Affected',
#        'Total Affected', 'CPI', 'Admin Units', 'Entry Date', 'Last Update'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plot the data
sns.lineplot(data=df, x=df.index, y='Total Affected')

# Increase the number of x-axis ticks (bins)
plt.xticks(rotation=45)  # Rotate labels for readability
plt.locator_params(axis='x', nbins=24)  # Set the number of bins (adjust '10' as needed)

plt.show()
# Out:
# <ipython-input-8-631683ad4ff5>:9: UserWarning: 'set_params()' not defined for locator of type <class 'matplotlib.dates.AutoDateLocator'>
#   plt.locator_params(axis='x', nbins=24)  # Set the number of bins (adjust '10' as needed)

# %%
sns.lineplot(data=df, x=df.index, y='Magnitude')
# Out:
# <Axes: xlabel='yearMonth', ylabel='Magnitude'>

# %%
df1 = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/FDS/00-01_data.xlsx')
df1
# Out:
#          Date         DisNo. Historic Classification Key Disaster Group  \
# 0  1970-01-01  2000-0020-IND       No    nat-met-ext-col        Natural
# 1  1970-01-01  2000-0306-IND       No    nat-bio-epi-vir        Natural
# 2  1970-01-01  2000-0308-IND       No    nat-bio-epi-bac        Natural
# 3  1970-01-01  2000-0323-IND       No    nat-met-sto-tro        Natural
# 4  1970-01-01  2000-0332-IND       No    nat-hyd-flo-fla        Natural
# 5  1970-01-01  2000-0358-IND       No    nat-hyd-mmw-lan        Natural
# 6  1970-01-01  2000-0415-IND       No    nat-hyd-mmw-lan        Natural
# 7  1970-01-01  2000-0444-IND       No    nat-hyd-flo-fla        Natural
# 8  1970-01-01  2000-0445-IND       No    nat-hyd-flo-riv        Natural
# 9  1970-01-01  2000-0459-IND       No    nat-bio-epi-bac        Natural
# 10 1970-01-01  2000-0498-IND       No    nat-hyd-mmw-lan        Natural
# 11 1970-01-01  2000-0534-IND       No    nat-hyd-flo-fla        Natural
# 12 1970-01-01  2000-0568-IND       No    nat-bio-epi-vir        Natural
# 13 1970-01-01  2000-0610-IND       No    nat-hyd-flo-riv        Natural
# 14 1970-01-01  2000-0698-IND       No    nat-bio-epi-dis        Natural
# 15 1970-01-01  2000-0709-IND       No    nat-bio-epi-vir        Natural
# 16 1970-01-01  2000-0738-IND       No    nat-hyd-flo-flo        Natural
# 17 1970-01-01  2000-0785-IND       No    nat-met-sto-tro        Natural
# 18 1970-01-01  2000-0795-IND       No    nat-bio-epi-vir        Natural
# 19 1970-01-01  2000-0874-IND       No    nat-bio-epi-vir        Natural
# 20 1970-01-01  2000-9222-IND       No    nat-cli-dro-dro        Natural
# 21 1970-01-01  2001-0011-IND       No    nat-met-ext-col        Natural
# 22 1970-01-01  2001-0033-IND       No    nat-geo-ear-gro        Natural
# 23 1970-01-01  2001-0061-IND       No    nat-bio-epi-dis        Natural
# 24 1970-01-01  2001-0243-IND       No    nat-hyd-flo-riv        Natural
# 25 1970-01-01  2001-0330-IND       No    nat-bio-epi-bac        Natural
# 26 1970-01-01  2001-0332-IND       No    nat-hyd-flo-riv        Natural
# 27 1970-01-01  2001-0337-IND       No    nat-met-sto-lig        Natural
# 28 1970-01-01  2001-0349-IND       No    nat-hyd-flo-flo        Natural
# 29 1970-01-01  2001-0387-IND       No    nat-hyd-flo-riv        Natural
# 30 1970-01-01  2001-0409-IND       No    nat-bio-epi-bac        Natural
# 31 1970-01-01  2001-0414-IND       No    nat-hyd-mmw-lan        Natural
# 32 1970-01-01  2001-0438-IND       No    nat-bio-epi-par        Natural
# 33 1970-01-01  2001-0465-IND       No    nat-hyd-flo-riv        Natural
# 34 1970-01-01  2001-0501-IND       No    nat-hyd-mmw-lan        Natural
# 35 1970-01-01  2001-0502-IND       No    nat-hyd-flo-flo        Natural
# 36 1970-01-01  2001-0515-IND       No    nat-hyd-flo-flo        Natural
# 37 1970-01-01  2001-0527-IND       No    nat-hyd-flo-fla        Natural
# 38 1970-01-01  2001-0584-IND       No    nat-met-sto-tro        Natural
# 39 1970-01-01  2001-0618-IND       No    nat-hyd-mmw-lan        Natural
# 40 1970-01-01  2001-0681-IND       No    nat-met-ext-col        Natural
# 41 1970-01-01  2001-0729-IND       No    nat-met-sto-tro        Natural
# 42 1970-01-01  2001-0794-IND       No    nat-hyd-flo-flo        Natural
#
#    Disaster Subgroup  Disaster Type              Disaster Subtype  ISO  \
# 0     Meteorological              3                     Cold wave  IND
# 1         Biological              2                 Viral disease  IND
# 2         Biological              2             Bacterial disease  IND
# 3     Meteorological              8              Tropical cyclone  IND
# 4       Hydrological              4                   Flash flood  IND
# 5       Hydrological              7               Landslide (wet)  IND
# 6       Hydrological              7               Landslide (wet)  IND
# 7       Hydrological              4                   Flash flood  IND
# 8       Hydrological              4                Riverine flood  IND
# 9         Biological              2             Bacterial disease  IND
# 10      Hydrological              7               Landslide (wet)  IND
# 11      Hydrological              4                   Flash flood  IND
# 12        Biological              2                 Viral disease  IND
# 13      Hydrological              4                Riverine flood  IND
# 14        Biological              2  Infectious disease (General)  IND
# 15        Biological              2                 Viral disease  IND
# 16      Hydrological              4               Flood (General)  IND
# 17    Meteorological              8              Tropical cyclone  IND
# 18        Biological              2                 Viral disease  IND
# 19        Biological              2                 Viral disease  IND
# 20    Climatological              0                       Drought  IND
# 21    Meteorological              3                     Cold wave  IND
# 22       Geophysical              1               Ground movement  IND
# 23        Biological              2  Infectious disease (General)  IND
# 24      Hydrological              4                Riverine flood  IND
# 25        Biological              2             Bacterial disease  IND
# 26      Hydrological              4                Riverine flood  IND
# 27    Meteorological              8       Lightning/Thunderstorms  IND
# 28      Hydrological              4               Flood (General)  IND
# 29      Hydrological              4                Riverine flood  IND
# 30        Biological              2             Bacterial disease  IND
# 31      Hydrological              7               Landslide (wet)  IND
# 32        Biological              2             Parasitic disease  IND
# 33      Hydrological              4                Riverine flood  IND
# 34      Hydrological              7               Landslide (wet)  IND
# 35      Hydrological              4               Flood (General)  IND
# 36      Hydrological              4               Flood (General)  IND
# 37      Hydrological              4                   Flash flood  IND
# 38    Meteorological              8              Tropical cyclone  IND
# 39      Hydrological              7               Landslide (wet)  IND
# 40    Meteorological              3                     Cold wave  IND
# 41    Meteorological              8              Tropical cyclone  IND
# 42      Hydrological              4               Flood (General)  IND
#
#    Country  ... End Year End Month End Day  Total Deaths  No. Affected  \
# 0    India  ...     2000         1       1    275.000000  5.141636e+06
# 1    India  ...     2000         5       1     84.000000  1.055000e+03
# 2    India  ...     2000         5       1    240.103448  1.920000e+02
# 3    India  ...     2000        10      17    240.103448  5.141636e+06
# 4    India  ...     2000         6      10     20.000000  3.000000e+06
# 5    India  ...     2000         6       1     43.000000  5.141636e+06
# 6    India  ...     2000         7      12     58.000000  7.000000e+03
# 7    India  ...     2000         7       1    130.000000  5.141636e+06
# 8    India  ...     2000         8       2    867.000000  2.200000e+07
# 9    India  ...     2000         7       1     27.000000  7.900000e+01
# 10   India  ...     2000         8      11     86.000000  5.141636e+06
# 11   India  ...     2000         8      23    179.000000  5.141636e+06
# 12   India  ...     2000         8       1     34.000000  1.160000e+02
# 13   India  ...     2000        10      21    884.000000  2.460000e+07
# 14   India  ...     2000        10       1     51.000000  5.141636e+06
# 15   India  ...     2000        10      12     14.000000  6.400000e+01
# 16   India  ...     2000        10      19      6.000000  5.340350e+05
# 17   India  ...     2000        11      29    240.103448  3.000000e+04
# 18   India  ...     2000        10      26     13.000000  2.870000e+02
# 19   India  ...     2000         8      31     19.000000  5.800000e+01
# 20   India  ...     2001         4       1     20.000000  5.000000e+07
# 21   India  ...     2001         1       1    125.000000  5.141636e+06
# 22   India  ...     2001         1      26  20005.000000  4.365000e+06
# 23   India  ...     2001         2       1     28.000000  4.200000e+01
# 24   India  ...     2001         6       5      5.000000  7.000000e+05
# 25   India  ...     2001         6      18     16.000000  8.300000e+01
# 26   India  ...     2001         7       8    100.000000  9.670000e+06
# 27   India  ...     2001         5      24     21.000000  5.141636e+06
# 28   India  ...     2001         6       1     28.000000  5.141636e+06
# 29   India  ...     2001         7       4     86.000000  4.000000e+04
# 30   India  ...     2001         8      28     33.000000  3.407800e+04
# 31   India  ...     2001         7      16     27.000000  5.141636e+06
# 32   India  ...     2001         8       1     12.000000  2.468600e+04
# 33   India  ...     2001         8       1    240.103448  4.000000e+05
# 34   India  ...     2001         8      14     16.000000  5.141636e+06
# 35   India  ...     2001         8       1     10.000000  5.141636e+06
# 36   India  ...     2001         8      20    158.000000  7.000000e+06
# 37   India  ...     2001         9       1     48.000000  2.800000e+06
# 38   India  ...     2001        10       1     78.000000  2.500000e+04
# 39   India  ...     2001        11       9     55.000000  5.141636e+06
# 40   India  ...     2001        12       1     48.000000  5.141636e+06
# 41   India  ...     2001         5      28    240.103448  5.141636e+06
# 42   India  ...     2001         9       7    146.000000  5.141636e+06
#
#    Total Affected        CPI  \
# 0    3.935890e+06  56.514291
# 1    1.055000e+03  56.514291
# 2    1.920000e+02  56.514291
# 3    3.935890e+06  56.514291
# 4    3.000000e+06  56.514291
# 5    3.935890e+06  56.514291
# 6    7.038000e+03  56.514291
# 7    3.935890e+06  56.514291
# 8    2.200000e+07  56.514291
# 9    7.900000e+01  56.514291
# 10   3.935890e+06  56.514291
# 11   2.520160e+05  56.514291
# 12   1.160000e+02  56.514291
# 13   2.460000e+07  56.514291
# 14   3.935890e+06  56.514291
# 15   6.400000e+01  56.514291
# 16   5.340350e+05  56.514291
# 17   3.000000e+04  56.514291
# 18   2.870000e+02  56.514291
# 19   5.800000e+01  56.514291
# 20   5.000000e+07  56.514291
# 21   3.935890e+06  58.111474
# 22   6.321812e+06  58.111474
# 23   4.200000e+01  58.111474
# 24   7.000000e+05  58.111474
# 25   8.300000e+01  58.111474
# 26   9.670000e+06  58.111474
# 27   3.935890e+06  58.111474
# 28   4.000000e+00  58.111474
# 29   4.000000e+04  58.111474
# 30   3.407800e+04  58.111474
# 31   3.935890e+06  58.111474
# 32   2.468600e+04  58.111474
# 33   4.000000e+05  58.111474
# 34   3.935890e+06  58.111474
# 35   3.600000e+01  58.111474
# 36   7.000000e+06  58.111474
# 37   2.800000e+06  58.111474
# 38   2.700000e+04  58.111474
# 39   3.935890e+06  58.111474
# 40   3.935890e+06  58.111474
# 41   3.935890e+06  58.111474
# 42   3.935890e+06  58.111474
#
#                                           Admin Units  Entry Date  Last Update
# 0   [{"adm1_code":1511,"adm1_name":"West Bengal"},...  2003-07-01   2023-09-25
# 1   [{"adm1_code":70081,"adm1_name":"Uttar Pradesh"}]  2003-07-01   2023-09-25
# 2   [{"adm1_code":70081,"adm1_name":"Uttar Pradesh"}]  2003-07-01   2023-09-25
# 3   [{"adm1_code":1485,"adm1_name":"Andhra Pradesh"}]  2003-07-01   2023-09-25
# 4   [{"adm2_code":17582,"adm2_name":"Golaghat"},{"...  2005-09-15   2023-09-25
# 5   [{"adm1_code":70082,"adm1_name":"Uttarakhand"}...  2003-07-01   2023-09-25
# 6   [{"adm2_code":70183,"adm2_name":"Mumbai Suburb...  2005-04-24   2023-09-25
# 7   [{"adm2_code":70041,"adm2_name":"Administrativ...  2003-07-01   2023-09-25
# 8   [{"adm1_code":1485,"adm1_name":"Andhra Pradesh...  2008-01-03   2023-09-25
# 9   [{"adm1_code":70081,"adm1_name":"Uttar Pradesh"}]  2003-07-01   2023-09-25
# 10  [{"adm2_code":17932,"adm2_name":"Pithoragarh"}...  2003-07-01   2023-09-25
# 11  [{"adm2_code":17547,"adm2_name":"Adilabad"},{"...  2006-02-23   2023-09-25
# 12  [{"adm1_code":70081,"adm1_name":"Uttar Pradesh"}]  2003-07-01   2023-09-25
# 13  [{"adm2_code":17946,"adm2_name":"Barddhaman"},...  2005-09-15   2023-09-25
# 14  [{"adm1_code":70081,"adm1_name":"Uttar Pradesh"}]  2003-07-01   2023-09-25
# 15  [{"adm1_code":70081,"adm1_name":"Uttar Pradesh"}]  2003-07-01   2023-09-25
# 16  [{"adm2_code":70293,"adm2_name":"North 24 Parg...  2003-07-01   2023-09-25
# 17  [{"adm1_code":1485,"adm1_name":"Andhra Pradesh...  2003-07-01   2023-09-25
# 18  [{"adm1_code":70081,"adm1_name":"Uttar Pradesh"}]  2003-07-01   2023-09-25
# 19  [{"adm1_code":70081,"adm1_name":"Uttar Pradesh"}]  2003-07-01   2023-09-25
# 20  [{"adm1_code":1485,"adm1_name":"Andhra Pradesh...  2008-01-03   2023-09-25
# 21  [{"adm1_code":1505,"adm1_name":"Punjab"},{"adm...  2003-07-01   2023-09-25
# 22  [{"adm2_code":17635,"adm2_name":"Ahmadabad"},{...  2014-04-04   2023-09-25
# 23  [{"adm1_code":70081,"adm1_name":"Uttar Pradesh"}]  2003-07-01   2023-09-25
# 24  [{"adm2_code":17577,"adm2_name":"Cachar"},{"ad...  2005-09-19   2023-09-25
# 25  [{"adm1_code":70081,"adm1_name":"Uttar Pradesh"}]  2003-07-01   2023-09-25
# 26  [{"adm2_code":17809,"adm2_name":"Cuttack"},{"a...  2005-09-20   2023-09-25
# 27  [{"adm1_code":70081,"adm1_name":"Uttar Pradesh"}]  2003-07-01   2023-09-25
# 28  [{"adm2_code":17701,"adm2_name":"Kasaragod"},{...  2003-07-01   2023-09-25
# 29  [{"adm2_code":17700,"adm2_name":"Idukki"},{"ad...  2005-09-20   2023-09-25
# 30  [{"adm1_code":70081,"adm1_name":"Uttar Pradesh"}]  2005-06-17   2023-09-25
# 31   [{"adm2_code":70286,"adm2_name":"Rudra Prayag"}]  2003-07-01   2023-09-25
# 32  [{"adm1_code":70081,"adm1_name":"Uttar Pradesh"}]  2003-07-01   2023-09-25
# 33  [{"adm2_code":17594,"adm2_name":"Aurangabad"},...  2003-07-01   2023-09-25
# 34         [{"adm2_code":17667,"adm2_name":"Chamba"}]  2003-07-01   2023-09-25
# 35           [{"adm1_code":1489,"adm1_name":"Delhi"}]  2003-07-01   2023-09-25
# 36  [{"adm2_code":17604,"adm2_name":"Gopalganj"},{...  2003-07-01   2023-09-25
# 37  [{"adm1_code":70081,"adm1_name":"Uttar Pradesh...  2003-07-01   2023-09-25
# 38  [{"adm1_code":1485,"adm1_name":"Andhra Pradesh"}]  2003-07-01   2023-09-25
# 39  [{"adm2_code":17709,"adm2_name":"Thiruvanantha...  2003-07-01   2023-09-25
# 40  [{"adm1_code":1506,"adm1_name":"Rajasthan"},{"...  2003-07-01   2023-09-25
# 41  [{"adm1_code":1490,"adm1_name":"Goa"},{"adm1_c...  2003-07-01   2023-09-25
# 42  [{"adm2_code":17604,"adm2_name":"Gopalganj"},{...  2006-07-20   2023-09-25
#
# [43 rows x 33 columns]

# %%
# Ensure 'End Day', 'End Month', and 'End Year' are integers or valid strings
df1['End Day'] = df1['End Day'].astype(str).str.zfill(2)  # Ensures day is two digits
df1['End Month'] = df1['End Month'].astype(str).str.zfill(2)  # Ensures month is two digits
df1['End Year'] = df1['End Year'].astype(str)  # Ensure year is a string

# Combine the columns to form a date
df1['yearMonth'] = pd.to_datetime(df1['End Year'] + '-' + df1['End Month'] + '-' + df1['End Day'], errors='coerce')

# Set the new column as the index
df1.set_index('yearMonth', inplace=True)

# Display the first few rows of the DataFrame
df1.head()
# Out:
#                  Date         DisNo. Historic Classification Key  \
# yearMonth
# 2000-01-01 1970-01-01  2000-0020-IND       No    nat-met-ext-col
# 2000-05-01 1970-01-01  2000-0306-IND       No    nat-bio-epi-vir
# 2000-05-01 1970-01-01  2000-0308-IND       No    nat-bio-epi-bac
# 2000-10-17 1970-01-01  2000-0323-IND       No    nat-met-sto-tro
# 2000-06-10 1970-01-01  2000-0332-IND       No    nat-hyd-flo-fla
#
#            Disaster Group Disaster Subgroup  Disaster Type   Disaster Subtype  \
# yearMonth
# 2000-01-01        Natural    Meteorological              3          Cold wave
# 2000-05-01        Natural        Biological              2      Viral disease
# 2000-05-01        Natural        Biological              2  Bacterial disease
# 2000-10-17        Natural    Meteorological              8   Tropical cyclone
# 2000-06-10        Natural      Hydrological              4        Flash flood
#
#             ISO Country  ... End Year End Month End Day Total Deaths  \
# yearMonth                ...
# 2000-01-01  IND   India  ...     2000        01      01   275.000000
# 2000-05-01  IND   India  ...     2000        05      01    84.000000
# 2000-05-01  IND   India  ...     2000        05      01   240.103448
# 2000-10-17  IND   India  ...     2000        10      17   240.103448
# 2000-06-10  IND   India  ...     2000        06      10    20.000000
#
#             No. Affected Total Affected        CPI  \
# yearMonth
# 2000-01-01  5.141636e+06   3.935890e+06  56.514291
# 2000-05-01  1.055000e+03   1.055000e+03  56.514291
# 2000-05-01  1.920000e+02   1.920000e+02  56.514291
# 2000-10-17  5.141636e+06   3.935890e+06  56.514291
# 2000-06-10  3.000000e+06   3.000000e+06  56.514291
#
#                                                   Admin Units  Entry Date  \
# yearMonth
# 2000-01-01  [{"adm1_code":1511,"adm1_name":"West Bengal"},...  2003-07-01
# 2000-05-01  [{"adm1_code":70081,"adm1_name":"Uttar Pradesh"}]  2003-07-01
# 2000-05-01  [{"adm1_code":70081,"adm1_name":"Uttar Pradesh"}]  2003-07-01
# 2000-10-17  [{"adm1_code":1485,"adm1_name":"Andhra Pradesh"}]  2003-07-01
# 2000-06-10  [{"adm2_code":17582,"adm2_name":"Golaghat"},{"...  2005-09-15
#
#             Last Update
# yearMonth
# 2000-01-01   2023-09-25
# 2000-05-01   2023-09-25
# 2000-05-01   2023-09-25
# 2000-10-17   2023-09-25
# 2000-06-10   2023-09-25
#
# [5 rows x 33 columns]

# %%
sns.lineplot(data=df1, x=df1.index, y='Total Affected')
# Out:
# <Axes: xlabel='yearMonth', ylabel='Total Affected'>

# %%
# Drop the 'Date' column
df1.drop(columns='Date', inplace=True)

# Display the first few rows of the DataFrame to confirm the change
df1.head()
# Out:
#                    DisNo. Historic Classification Key Disaster Group  \
# yearMonth
# 2000-01-01  2000-0020-IND       No    nat-met-ext-col        Natural
# 2000-05-01  2000-0306-IND       No    nat-bio-epi-vir        Natural
# 2000-05-01  2000-0308-IND       No    nat-bio-epi-bac        Natural
# 2000-10-17  2000-0323-IND       No    nat-met-sto-tro        Natural
# 2000-06-10  2000-0332-IND       No    nat-hyd-flo-fla        Natural
#
#            Disaster Subgroup  Disaster Type   Disaster Subtype  ISO Country  \
# yearMonth
# 2000-01-01    Meteorological              3          Cold wave  IND   India
# 2000-05-01        Biological              2      Viral disease  IND   India
# 2000-05-01        Biological              2  Bacterial disease  IND   India
# 2000-10-17    Meteorological              8   Tropical cyclone  IND   India
# 2000-06-10      Hydrological              4        Flash flood  IND   India
#
#                 Subregion  ... End Year End Month End Day Total Deaths  \
# yearMonth                  ...
# 2000-01-01  Southern Asia  ...     2000        01      01   275.000000
# 2000-05-01  Southern Asia  ...     2000        05      01    84.000000
# 2000-05-01  Southern Asia  ...     2000        05      01   240.103448
# 2000-10-17  Southern Asia  ...     2000        10      17   240.103448
# 2000-06-10  Southern Asia  ...     2000        06      10    20.000000
#
#             No. Affected  Total Affected        CPI  \
# yearMonth
# 2000-01-01  5.141636e+06    3.935890e+06  56.514291
# 2000-05-01  1.055000e+03    1.055000e+03  56.514291
# 2000-05-01  1.920000e+02    1.920000e+02  56.514291
# 2000-10-17  5.141636e+06    3.935890e+06  56.514291
# 2000-06-10  3.000000e+06    3.000000e+06  56.514291
#
#                                                   Admin Units  Entry Date  \
# yearMonth
# 2000-01-01  [{"adm1_code":1511,"adm1_name":"West Bengal"},...  2003-07-01
# 2000-05-01  [{"adm1_code":70081,"adm1_name":"Uttar Pradesh"}]  2003-07-01
# 2000-05-01  [{"adm1_code":70081,"adm1_name":"Uttar Pradesh"}]  2003-07-01
# 2000-10-17  [{"adm1_code":1485,"adm1_name":"Andhra Pradesh"}]  2003-07-01
# 2000-06-10  [{"adm2_code":17582,"adm2_name":"Golaghat"},{"...  2005-09-15
#
#             Last Update
# yearMonth
# 2000-01-01   2023-09-25
# 2000-05-01   2023-09-25
# 2000-05-01   2023-09-25
# 2000-10-17   2023-09-25
# 2000-06-10   2023-09-25
#
# [5 rows x 32 columns]

# %%
# Ensure 'End Day', 'End Month', and 'End Year' columns are correctly combined to create 'yearMonth'
df1['End Day'] = df1['End Day'].astype(str).str.zfill(2)
df1['End Month'] = df1['End Month'].astype(str).str.zfill(2)
df1['End Year'] = df1['End Year'].astype(str)

# Create the 'yearMonth' column
df1['yearMonth'] = pd.to_datetime(df1['End Year'] + '-' + df1['End Month'] + '-' + df1['End Day'], errors='coerce')

# Set the 'yearMonth' column as the index directly (no need to sort if already sorted)
df1.set_index('yearMonth', inplace=True)

# Display the first few rows to verify the index is set correctly
df1.head()
# Out:
#                    DisNo. Historic Classification Key Disaster Group  \
# yearMonth
# 2000-01-01  2000-0020-IND       No    nat-met-ext-col        Natural
# 2000-05-01  2000-0306-IND       No    nat-bio-epi-vir        Natural
# 2000-05-01  2000-0308-IND       No    nat-bio-epi-bac        Natural
# 2000-10-17  2000-0323-IND       No    nat-met-sto-tro        Natural
# 2000-06-10  2000-0332-IND       No    nat-hyd-flo-fla        Natural
#
#            Disaster Subgroup  Disaster Type   Disaster Subtype  ISO Country  \
# yearMonth
# 2000-01-01    Meteorological              3          Cold wave  IND   India
# 2000-05-01        Biological              2      Viral disease  IND   India
# 2000-05-01        Biological              2  Bacterial disease  IND   India
# 2000-10-17    Meteorological              8   Tropical cyclone  IND   India
# 2000-06-10      Hydrological              4        Flash flood  IND   India
#
#                 Subregion  ... End Year End Month End Day Total Deaths  \
# yearMonth                  ...
# 2000-01-01  Southern Asia  ...     2000        01      01   275.000000
# 2000-05-01  Southern Asia  ...     2000        05      01    84.000000
# 2000-05-01  Southern Asia  ...     2000        05      01   240.103448
# 2000-10-17  Southern Asia  ...     2000        10      17   240.103448
# 2000-06-10  Southern Asia  ...     2000        06      10    20.000000
#
#             No. Affected  Total Affected        CPI  \
# yearMonth
# 2000-01-01  5.141636e+06    3.935890e+06  56.514291
# 2000-05-01  1.055000e+03    1.055000e+03  56.514291
# 2000-05-01  1.920000e+02    1.920000e+02  56.514291
# 2000-10-17  5.141636e+06    3.935890e+06  56.514291
# 2000-06-10  3.000000e+06    3.000000e+06  56.514291
#
#                                                   Admin Units  Entry Date  \
# yearMonth
# 2000-01-01  [{"adm1_code":1511,"adm1_name":"West Bengal"},...  2003-07-01
# 2000-05-01  [{"adm1_code":70081,"adm1_name":"Uttar Pradesh"}]  2003-07-01
# 2000-05-01  [{"adm1_code":70081,"adm1_name":"Uttar Pradesh"}]  2003-07-01
# 2000-10-17  [{"adm1_code":1485,"adm1_name":"Andhra Pradesh"}]  2003-07-01
# 2000-06-10  [{"adm2_code":17582,"adm2_name":"Golaghat"},{"...  2005-09-15
#
#             Last Update
# yearMonth
# 2000-01-01   2023-09-25
# 2000-05-01   2023-09-25
# 2000-05-01   2023-09-25
# 2000-10-17   2023-09-25
# 2000-06-10   2023-09-25
#
# [5 rows x 32 columns]

# %%
# Split the dataset into training and test sets (80% training, 20% testing)
train_size = int(len(df1) * 0.8)
train, test = df1[:train_size], df1[train_size:]

# %%
# 1. Moving Average Model
def moving_average_forecast(data, window_size):
    return data.rolling(window=window_size).mean()

# Using a window size of 12 (monthly rolling average for daily data)
moving_avg_forecast = moving_average_forecast(train['Total Affected'], window_size=12).dropna()

# Plot the results for Moving Average
plt.figure(figsize=(10, 6))
plt.plot(train.index, train['Total Affected'], label='Train Data')
plt.plot(moving_avg_forecast.index, moving_avg_forecast, label='Moving Average Forecast', linestyle='--')
plt.title("Moving Average Forecast (Window Size = 12)")
plt.legend()
plt.show()

# %%
# 2. Exponential Smoothing Model
exp_smoothing_model = ExponentialSmoothing(train['Total Affected'], trend='add').fit()
exp_smoothing_forecast = exp_smoothing_model.forecast(len(test))

# Plot Exponential Smoothing forecast
plt.figure(figsize=(10, 6))
plt.plot(train.index, train['Total Affected'], label='Train Data')
plt.plot(test.index, exp_smoothing_forecast, label='Exponential Smoothing Forecast (Without Seasonality)', linestyle='--')
plt.title("Exponential Smoothing Forecast (Without Seasonality)")
plt.legend()
plt.show()

# Calculate MAPE and RMSE for Exponential Smoothing
mape_exp_smoothing = mean_absolute_percentage_error(test['Total Affected'], exp_smoothing_forecast)
rmse_exp_smoothing = np.sqrt(mean_squared_error(test['Total Affected'], exp_smoothing_forecast))

print(f"Exponential Smoothing - MAPE: {mape_exp_smoothing}, RMSE: {rmse_exp_smoothing}")
